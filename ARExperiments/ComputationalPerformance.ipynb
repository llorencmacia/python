# %% [markdown]
# # Computational performance

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rCFdata = np.genfromtxt("/home/PROJECTS/AR/rhoCentralFoam/2DblockMeshSteady/Mesh10/p0constantL1Turb/p0_100/postProcessing/flowRate/0/surfaceFieldValue.dat")
rCFdata = np.transpose(rCFdata)

# %%
plt.plot(rCFdata[0,:300000],np.abs(rCFdata[1,:300000]),'k-')
plt.xlabel('t')
plt.ylabel(r'$\dot{m}_s$')
plt.tight_layout()
plt.savefig("rCFDPerformance.png")

# %%
HiSAdata = np.genfromtxt("/home/PROJECTS/AR/HiSA/cases_ofblockmeshdicthelper/Mesh10/Steady/p0_100Steady/postProcessing/flowRate/0/surfaceFieldValue.dat")
HiSAdata = np.transpose(HiSAdata)

# %%
plt.plot(HiSAdata[0,:15000],-HiSAdata[1,:15000],'k-')
plt.xlabel('it')
plt.ylabel(r'$\dot{m}_s$')
plt.tight_layout()
plt.savefig('rHiSAPerformance.png')
